# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
odf=pd.read_csv("/kaggle/input/magpie-perov/CBFV_magpie_extracted_features.csv")

# %%
odf
# Out:
#       composition  formation_energy (eV/atom)  band_gap (eV)  sum_Number  \
# 0      Ac1 Al1 O3                   -3.690019         4.1024       126.0
# 1      Ac1 Cr1 O3                   -3.138972         2.0031       137.0
# 2      Ac1 Cu1 O3                   -2.422892         0.0000       142.0
# 3      Ac1 Fe1 O3                   -2.771539         0.9888       139.0
# 4      Ac1 Ga1 O3                   -3.063253         2.8959       144.0
# ...           ...                         ...            ...         ...
# 1007   Nd1 Lu1 S3                   -2.393228         0.8052       179.0
# 1008  Nd1 Lu1 Se3                   -2.187057         0.4956       233.0
# 1009   Nd1 Mn1 O3                   -2.963479         1.8980       109.0
# 1010  Nd1 Ni1 Ge3                   -0.597557         0.0000       184.0
# 1011   Nd1 Ni1 O3                   -2.425267         0.0000       112.0
#
#       sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  sum_Column  \
# ...

# %%
df= odf.drop(columns=['composition', 'formation_energy (eV/atom)', 'band_gap (eV)'])
df
# Out:
#       sum_Number  sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  \
# 0          126.0                348.0        301.979739       2420.87
# 1          137.0                324.0        326.994300       3667.40
# 2          142.0                339.0        338.544200       2845.17
# 3          139.0                330.0        330.843200       3298.40
# 4          144.0                349.0        344.721200       1790.31
# ...          ...                  ...               ...           ...
# 1007       179.0                324.0        415.403800       4395.08
# 1008       233.0                327.0        556.088800       4712.00
# 1009       109.0                332.0        247.178245       2977.40
# 1010       184.0                317.0        420.855400       6656.20
# 1011       112.0                341.0        250.933600       3186.40
#
#       sum_Column  sum_Row  sum_CovalentRadius  sum_Electronegativity  \
# ...

# %%
# Setup: separate X (308 CBFV features), y (both targets), and composition groups
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit

# X: 308 features after CBFV Oliynyk extraction
X = odf.drop(columns=['composition', 'formation_energy (eV/atom)', 'band_gap (eV)']).copy()
y_df = odf[['formation_energy (eV/atom)', 'band_gap (eV)']].copy()
comp_df = odf[['composition']].copy()

# Outer split: 80% train+val, 20% test (grouped by composition)
gss_outer = GroupShuffleSplit(n_splits=1, test_size=0.20, random_state=42)
trainval_idx, test_idx = next(gss_outer.split(X, y_df, groups=comp_df['composition']))

X_trainval = X.iloc[trainval_idx].reset_index(drop=True)
X_test     = X.iloc[test_idx].reset_index(drop=True)
y_trainval = y_df.iloc[trainval_idx].reset_index(drop=True)
y_test     = y_df.iloc[test_idx].reset_index(drop=True)
comp_trainval = comp_df.iloc[trainval_idx]['composition'].reset_index(drop=True)
comp_test     = comp_df.iloc[test_idx]['composition'].reset_index(drop=True)

# Inner split: from the 80% trainval, create train and val (e.g., 80/20 -> overall 64/16)
gss_inner = GroupShuffleSplit(n_splits=1, test_size=0.20, random_state=42)
train_idx, val_idx = next(gss_inner.split(X_trainval, y_trainval, groups=comp_trainval))

X_train = X_trainval.iloc[train_idx].reset_index(drop=True)
X_val   = X_trainval.iloc[val_idx].reset_index(drop=True)
y_train = y_trainval.iloc[train_idx].reset_index(drop=True)
y_val   = y_trainval.iloc[val_idx].reset_index(drop=True)
comp_train = comp_trainval.iloc[train_idx].reset_index(drop=True)
comp_val   = comp_trainval.iloc[val_idx].reset_index(drop=True)

# Select current target: formation energy
yfe_train = y_train['formation_energy (eV/atom)']
yfe_val   = y_val['formation_energy (eV/atom)']
yfe_test  = y_test['formation_energy (eV/atom)']

# Optional sanity checks: no composition overlap across splits
assert set(comp_train).isdisjoint(set(comp_val))
assert set(comp_train).isdisjoint(set(comp_test))
assert set(comp_val).isdisjoint(set(comp_test))

# Shapes
print("Train shapes:", X_train.shape, yfe_train.shape)
print("Val shapes:",   X_val.shape,   yfe_val.shape)
print("Test shapes:",  X_test.shape,  yfe_test.shape)
# Out:
# Train shapes: (647, 154) (647,)
# Val shapes: (162, 154) (162,)
# Test shapes: (203, 154) (203,)

# %%
X
# Out:
#       sum_Number  sum_MendeleevNumber  sum_AtomicWeight  sum_MeltingT  \
# 0          126.0                348.0        301.979739       2420.87
# 1          137.0                324.0        326.994300       3667.40
# 2          142.0                339.0        338.544200       2845.17
# 3          139.0                330.0        330.843200       3298.40
# 4          144.0                349.0        344.721200       1790.31
# ...          ...                  ...               ...           ...
# 1007       179.0                324.0        415.403800       4395.08
# 1008       233.0                327.0        556.088800       4712.00
# 1009       109.0                332.0        247.178245       2977.40
# 1010       184.0                317.0        420.855400       6656.20
# 1011       112.0                341.0        250.933600       3186.40
#
#       sum_Column  sum_Row  sum_CovalentRadius  sum_Electronegativity  \
# ...

# %%
y_df
# Out:
#       formation_energy (eV/atom)  band_gap (eV)
# 0                      -3.690019         4.1024
# 1                      -3.138972         2.0031
# 2                      -2.422892         0.0000
# 3                      -2.771539         0.9888
# 4                      -3.063253         2.8959
# ...                          ...            ...
# 1007                   -2.393228         0.8052
# 1008                   -2.187057         0.4956
# 1009                   -2.963479         1.8980
# 1010                   -0.597557         0.0000
# 1011                   -2.425267         0.0000
#
# [1012 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import mutual_info_regression

# Inputs assumed from previous step:
# X_train, X_val, X_test: feature DataFrames
# yfe_train, yfe_val, yfe_test: Series for formation energy

def compute_mi_ranking(X, y, n_neighbors=5, n_repeats=8, base_seed=42):
    """
    Compute mutual information scores for continuous target using multiple seeds, averaged.
    Fits only on provided X, y (should be training split).
    """
    feats = X.columns.to_list()
    all_runs = []
    for i in range(n_repeats):
        seed = base_seed + i
        mi = mutual_info_regression(
            X.values, y.values,
            n_neighbors=n_neighbors,
            random_state=seed
        )
        all_runs.append(mi)
    all_runs = np.vstack(all_runs)
    mi_mean = all_runs.mean(axis=0)
    mi_std  = all_runs.std(axis=0)
    out = pd.DataFrame({
        "feature": feats,
        "mi_mean": mi_mean,
        "mi_std": mi_std
    }).sort_values("mi_mean", ascending=False).reset_index(drop=True)
    out["rank"] = np.arange(1, len(out)+1)
    return out

mi_rank = compute_mi_ranking(X_train, yfe_train, n_neighbors=5, n_repeats=8, base_seed=42)

# Inspect top features
mi_rank.head(30)
# Out:
#                     feature   mi_mean    mi_std  rank
# 0    mode_Electronegativity  0.845006  0.001845     1
# 1       max_MendeleevNumber  0.844046  0.002999     2
# 2     dev_Electronegativity  0.808828  0.000694     3
# 3     sum_Electronegativity  0.803477  0.000701     4
# 4     avg_Electronegativity  0.803238  0.000385     5
# 5      mode_MendeleevNumber  0.795360  0.003046     6
# 6               mode_Number  0.776473  0.004823     7
# 7                sum_Column  0.770628  0.006456     8
# 8                avg_Column  0.770518  0.004762     9
# 9         mode_AtomicWeight  0.763637  0.003605    10
# 10         mode_GSvolume_pa  0.746486  0.003270    11
# 11  range_Electronegativity  0.736564  0.002777    12
# 12          min_GSvolume_pa  0.733800  0.002570    13
# 13               min_Number  0.733220  0.005649    14
# 14       min_CovalentRadius  0.719564  0.004920    15
# 15         min_AtomicWeight  0.717884  0.001835    16
# ...

# %%
mi_rank.head(50)
# Out:
#                     feature   mi_mean    mi_std  rank
# 0    mode_Electronegativity  0.845006  0.001845     1
# 1       max_MendeleevNumber  0.844046  0.002999     2
# 2     dev_Electronegativity  0.808828  0.000694     3
# 3     sum_Electronegativity  0.803477  0.000701     4
# 4     avg_Electronegativity  0.803238  0.000385     5
# 5      mode_MendeleevNumber  0.795360  0.003046     6
# 6               mode_Number  0.776473  0.004823     7
# 7                sum_Column  0.770628  0.006456     8
# 8                avg_Column  0.770518  0.004762     9
# 9         mode_AtomicWeight  0.763637  0.003605    10
# 10         mode_GSvolume_pa  0.746486  0.003270    11
# 11  range_Electronegativity  0.736564  0.002777    12
# 12          min_GSvolume_pa  0.733800  0.002570    13
# 13               min_Number  0.733220  0.005649    14
# 14       min_CovalentRadius  0.719564  0.004920    15
# 15         min_AtomicWeight  0.717884  0.001835    16
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(mi_rank['rank'], mi_rank['mi_mean'], marker='o')
plt.xlabel('Feature Rank')
plt.ylabel('MI Mean')
plt.title('MI Mean vs Feature Rank')
plt.grid(True)
plt.show()

# %%
pip install pymrmr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pymrmr: filename=pymrmr-0.1.11-cp311-cp311-linux_x86_64.whl size=400975 sha256=627efb9259fd17bf17728b5c7ba616ba9383dc7c9ed8ebf7e2606b9ec3a8a00c
#   Stored in directory: /root/.cache/pip/wheels/a0/d7/97/71bca023a0dbdceab24a556649d661e71114f4eaaf4dda56d6
# Successfully built pymrmr
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymrmr

# Keep only features above threshold
top_features = mi_rank[mi_rank['mi_mean'] >= 0.4]['feature'].tolist()
X_top = X_train[top_features]

# Combine with target
df_mrmr = X_top.copy()
df_mrmr['target'] = yfe_train.values  # target at the end

# %%
df_mrmr
# Out:
#      mode_Electronegativity  max_MendeleevNumber  dev_Electronegativity  \
# 0                      3.44                 87.0                 1.0008
# 1                      3.44                 87.0                 0.9888
# 2                      3.44                 87.0                 0.9480
# 3                      3.44                 87.0                 0.9528
# 4                      3.44                 87.0                 1.0152
# ..                      ...                  ...                    ...
# 642                    1.81                 74.0                 0.2456
# 643                    1.81                 74.0                 0.2520
# 644                    2.58                 88.0                 0.6600
# 645                    3.44                 87.0                 1.0056
# 646                    3.44                 87.0                 0.9192
#
#      sum_Electronegativity  avg_Electronegativity  mode_MendeleevNumber  \
# ...

# %%
# Run MRMR feature selection
final_selected_features = pymrmr.mRMR(df_mrmr, 'MIQ', 30)

# Print before cleaning
print("Selected features by MRMR (raw):", final_selected_features)

# Remove 'target' if it appears in the list
final_selected_features = [f for f in final_selected_features if f != 'target']

# Print after cleaning
print("Final selected features (cleaned):", final_selected_features)
# Out:
# Selected features by MRMR (raw): ['mode_AtomicWeight', 'max_Electronegativity', 'avg_Electronegativity', 'dev_Electronegativity', 'sum_Electronegativity', 'mode_Row', 'target', 'mode_GSvolume_pa', 'mode_CovalentRadius', 'range_Electronegativity', 'avg_Column', 'dev_NpUnfilled', 'mode_MendeleevNumber', 'mode_MeltingT', 'mode_Number', 'min_CovalentRadius', 'dev_NpValence', 'min_MeltingT', 'mode_SpaceGroupNumber', 'sum_NpValence', 'mode_NValence', 'max_MendeleevNumber', 'dev_NdValence', 'avg_CovalentRadius', 'avg_NpValence', 'min_AtomicWeight', 'min_SpaceGroupNumber', 'min_GSvolume_pa', 'mode_Column', 'min_Number']
# ...

# %%
final_selected_features
# Out:
# ['mode_AtomicWeight',
#  'max_Electronegativity',
#  'avg_Electronegativity',
#  'dev_Electronegativity',
#  'sum_Electronegativity',
#  'mode_Row',
#  'mode_GSvolume_pa',
#  'mode_CovalentRadius',
#  'range_Electronegativity',
#  'avg_Column',
#  'dev_NpUnfilled',
#  'mode_MendeleevNumber',
#  'mode_MeltingT',
#  'mode_Number',
#  'min_CovalentRadius',
#  'dev_NpValence',
#  'min_MeltingT',
#  'mode_SpaceGroupNumber',
#  'sum_NpValence',
#  'mode_NValence',
#  'max_MendeleevNumber',
#  'dev_NdValence',
#  'avg_CovalentRadius',
#  'avg_NpValence',
#  'min_AtomicWeight',
#  'min_SpaceGroupNumber',
#  'min_GSvolume_pa',
#  'mode_Column',
#  'min_Number']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pandas as pd
import numpy as np

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train[final_selected_features])
X_val_scaled   = scaler_X.transform(X_val[final_selected_features])
X_test_scaled  = scaler_X.transform(X_test[final_selected_features])
print(X_train_scaled.shape)
print(X_val_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (647, 29)
# (162, 29)
# (203, 29)

# %%
# Target scaling
yfe_train_array = yfe_train.values.reshape(-1,1)
yfe_val_array   = yfe_val.values.reshape(-1,1)
yfe_test_array  = yfe_test.values.reshape(-1,1)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(yfe_train_array).ravel()
y_val_scaled   = scaler_y.transform(yfe_val_array).ravel()
y_test_scaled  = scaler_y.transform(yfe_test_array).ravel()

# %%
yfe_train
# Out:
# 0     -3.690019
# 1     -3.138972
# 2     -2.771539
# 3     -3.063253
# 4     -2.973630
#          ...
# 642   -0.687126
# 643   -0.724150
# 644   -2.393228
# 645   -2.963479
# 646   -2.425267
# Name: formation_energy (eV/atom), Length: 647, dtype: float64

# %%
y_train_scaled.shape
# Out:
# (647,)

# %%
# -----------------------------
#  Define models
# -----------------------------
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

models = {
    'LinearRegression': LinearRegression(),
    'Ridge': Ridge(alpha=1.0),
    'Lasso': Lasso(alpha=0.01),
    'RandomForest': RandomForestRegressor(n_estimators=200, random_state=42),
    'SVR': SVR(kernel='rbf', C=10, gamma='scale'),
    'AdaBoost': AdaBoostRegressor(n_estimators=200, random_state=42),
    'GradientBoosting': GradientBoostingRegressor(n_estimators=200, random_state=42),
    'XGBoost': XGBRegressor(n_estimators=200, random_state=42, eval_metric='rmse', verbosity=0),
    'CatBoost': CatBoostRegressor(n_estimators=200, random_state=42, verbose=0),
    'LightGBM': LGBMRegressor(n_estimators=200, random_state=42)
}

# -----------------------------
# Train, predict, evaluate
# -----------------------------
results = []

for name, model in models.items():
    # Fit model
    model.fit(X_train_scaled, y_train_scaled)
    
    # Predict
    y_train_pred = scaler_y.inverse_transform(model.predict(X_train_scaled).reshape(-1,1)).ravel()
    y_val_pred   = scaler_y.inverse_transform(model.predict(X_val_scaled).reshape(-1,1)).ravel()
    y_test_pred  = scaler_y.inverse_transform(model.predict(X_test_scaled).reshape(-1,1)).ravel()
    
    # Metrics
    for split, y_true, y_pred in zip(['train','val','test'],
                                     [yfe_train, yfe_val, yfe_test],
                                     [y_train_pred, y_val_pred, y_test_pred]):
        r2   = r2_score(y_true, y_pred)
        mse  = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        mae  = mean_absolute_error(y_true, y_pred)
    

        results.append({
            'Model': name,
            'Split': split,
            'R2': r2,
            'MSE': mse,
            'MAE': mae,
            'RMSE': rmse
            
        })

# -----------------------------
#  Create results DataFrame
# -----------------------------
results_df = pd.DataFrame(results)
results_df
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001015 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1690
# [LightGBM] [Info] Number of data points in the train set: 647, number of used features: 29
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
X_train_scaled.shape
# Out:
# (647, 29)

# %%
# -----------------------------
# Imports
# -----------------------------
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import pandas as pd

# -----------------------------
# Define models
# -----------------------------
models = {
    'LinearRegression': LinearRegression(),
    'Ridge': Ridge(),
    'Lasso': Lasso(),
    'RandomForest': RandomForestRegressor(random_state=42),
    'SVR': SVR(kernel='rbf', C=10, gamma='scale'),
    'AdaBoost': AdaBoostRegressor(random_state=42),
    'GradientBoosting': GradientBoostingRegressor(random_state=42),
    'XGBoost': XGBRegressor(random_state=42, eval_metric='rmse', verbosity=0),
    'CatBoost': CatBoostRegressor(random_state=42, verbose=0),  # No n_estimators here
    'LightGBM': LGBMRegressor(random_state=42)
}

# -----------------------------
# Hyperparameter grids
# -----------------------------
param_grids = {
    'Ridge': {'alpha': [0.01, 0.1, 1, 10, 100]},
    'Lasso': {'alpha': [0.001, 0.01, 0.1, 1]},
    'RandomForest': {
        'n_estimators': [100, 200, 500],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    },
    'AdaBoost': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.5, 1.0]
    },
    'GradientBoosting': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 10]
    },
    'XGBoost': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 10]
    },
    'CatBoost': {
        'iterations': [100, 200, 500],  # use iterations instead of n_estimators
        'learning_rate': [0.01, 0.05, 0.1],
        'depth': [3, 5, 7]
    },
    'LightGBM': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth': [-1, 5, 10]
    }
}

# -----------------------------
# Hyperparameter tuning loop
# -----------------------------
tuned_results = []

for name, model in models.items():
    print(f"Tuning {name}...")
    
    if name in param_grids:
        grid = GridSearchCV(model, param_grids[name], cv=3, scoring='r2', n_jobs=-1)
        grid.fit(X_train_scaled, y_train_scaled)
        best_model = grid.best_estimator_
        best_params = grid.best_params_
    else:
        # LinearRegression or models without grid
        best_model = model
        best_model.fit(X_train_scaled, y_train_scaled)
        best_params = "Default"
    
    # Predict on test set
    y_test_pred = scaler_y.inverse_transform(best_model.predict(X_test_scaled).reshape(-1,1)).ravel()
    
    # Metrics
    mse = mean_squared_error(yfe_test, y_test_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(yfe_test, y_test_pred)
    r2 = r2_score(yfe_test, y_test_pred)
    
    tuned_results.append({
        'Model': name,
        'R2': r2,
        'MSE': mse,
        'MAE': mae,
        'RMSE': rmse,
        'Best_Params': best_params
    })

# -----------------------------
# Results DataFrame
# -----------------------------
tuned_results_df = pd.DataFrame(tuned_results).sort_values(by='R2', ascending=False).reset_index(drop=True)
print(tuned_results_df)
# Out:
# Tuning LinearRegression...
# Tuning Ridge...
# Tuning Lasso...
# Tuning RandomForest...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.495e-01, tolerance: 4.173e-02
#   model = cd_fast.enet_coordinate_descent(
# Tuning SVR...
# Tuning AdaBoost...
# Tuning GradientBoosting...
# Tuning XGBoost...
# Tuning CatBoost...
# Tuning LightGBM...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1217
# [LightGBM] [Info] Number of data points in the train set: 431, number of used features: 29
# [LightGBM] [Info] Start training from score -0.027063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
tuned_results_df
# Out:
#               Model        R2       MSE       MAE      RMSE  \
# 0          LightGBM  0.965670  0.033471  0.129892  0.182952
# 1           XGBoost  0.961083  0.037944  0.136130  0.194793
# 2          CatBoost  0.957215  0.041715  0.141691  0.204243
# 3  GradientBoosting  0.956264  0.042642  0.147488  0.206500
# 4               SVR  0.951605  0.047185  0.152097  0.217222
# 5      RandomForest  0.950637  0.048129  0.147951  0.219383
# 6          AdaBoost  0.895833  0.101563  0.250636  0.318689
# 7             Lasso  0.836005  0.159895  0.314942  0.399869
# 8             Ridge  0.834028  0.161823  0.312256  0.402273
# 9  LinearRegression  0.833651  0.162190  0.310233  0.402729
#
#                                          Best_Params
# 0  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 1  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 2  {'depth': 5, 'iterations': 500, 'learning_rate...
# 3  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# ...

# %%
tuned_results_df
# Out:
#               Model        R2       MSE       MAE      RMSE  \
# 0          LightGBM  0.965670  0.033471  0.129892  0.182952
# 1           XGBoost  0.961083  0.037944  0.136130  0.194793
# 2          CatBoost  0.957215  0.041715  0.141691  0.204243
# 3  GradientBoosting  0.956264  0.042642  0.147488  0.206500
# 4               SVR  0.951605  0.047185  0.152097  0.217222
# 5      RandomForest  0.950637  0.048129  0.147951  0.219383
# 6          AdaBoost  0.895833  0.101563  0.250636  0.318689
# 7             Lasso  0.836005  0.159895  0.314942  0.399869
# 8             Ridge  0.834028  0.161823  0.312256  0.402273
# 9  LinearRegression  0.833651  0.162190  0.310233  0.402729
#
#                                          Best_Params
# 0  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 1  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 2  {'depth': 5, 'iterations': 500, 'learning_rate...
# 3  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# ...

# %%
# -----------------------------
# 1. Export results to CSV
# -----------------------------
tuned_results_df.to_csv("magpie_model_tuning_results.csv", index=False)
print("Tuning results saved to 'model_tuning_results.csv'")

# -----------------------------
# 2. Identify best model
# -----------------------------
best_model_info = tuned_results_df.iloc[0]  # Best R2
best_model_name = best_model_info['Model']
best_params = best_model_info['Best_Params']

print(f"Best Model: {best_model_name}")
print(f"Best Params: {best_params}")

# -----------------------------
# 3. Re-fit best model with best params
# -----------------------------
import joblib

# Dictionary mapping model names to classes
model_classes = {
    'LinearRegression': LinearRegression,
    'Ridge': Ridge,
    'Lasso': Lasso,
    'RandomForest': RandomForestRegressor,
    'SVR': SVR,
    'AdaBoost': AdaBoostRegressor,
    'GradientBoosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'CatBoost': CatBoostRegressor,
    'LightGBM': LGBMRegressor
}

# Handle default params case
if best_params == "Default":
    final_model = model_classes[best_model_name]()
else:
    if best_model_name == 'RandomForest' or best_model_name == 'AdaBoost' or best_model_name == 'GradientBoosting':
        final_model = model_classes[best_model_name](random_state=42, **best_params)
    elif best_model_name == 'XGBoost':
        final_model = XGBRegressor(random_state=42, eval_metric='rmse', verbosity=0, **best_params)
    elif best_model_name == 'CatBoost':
        final_model = CatBoostRegressor(random_state=42, verbose=0, **best_params)
    elif best_model_name == 'LightGBM':
        final_model = LGBMRegressor(random_state=42, **best_params)
    else:
        final_model = model_classes[best_model_name](**best_params)

# Fit on full training data
final_model.fit(X_train_scaled, y_train_scaled)

# -----------------------------
# 4. Save the model
# -----------------------------
model_filename = f"best_model_{best_model_name}.pkl"
joblib.dump(final_model, model_filename)
print(f"Best model saved as '{model_filename}'")
# Out:
# Tuning results saved to 'model_tuning_results.csv'
# Best Model: LightGBM
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1690
# [LightGBM] [Info] Number of data points in the train set: 647, number of used features: 29
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Melt the DataFrame for easier plotting
metrics_df = tuned_results_df.melt(
    id_vars='Model', 
    value_vars=['R2', 'MSE', 'MAE', "RMSE"], 
    var_name='Metric', 
    value_name='Value'
)

plt.figure(figsize=(16,7))
sns.set_style("whitegrid")

# Create barplot
ax = sns.barplot(
    x='Model', 
    y='Value', 
    hue='Metric', 
    data=metrics_df, 
    palette=['#1f77b4', '#ff7f0e', '#2ca02c','#FDDA0D']  # appealing distinct colors
)

plt.title('Comparison of R², MSE, and MAE for All Models -magpie- formation_energy', fontsize=18, fontweight='bold')
plt.ylabel('Score / Error', fontsize=14)
plt.xlabel('Model', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Metric', fontsize=12, title_fontsize=13)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.3f}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='bottom', 
                fontsize=10, color='black', rotation=0)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(yfe_test, y_test_pred, alpha=0.7)
plt.plot([yfe_test.min(), yfe_test.max()],
         [yfe_test.min(), yfe_test.max()], 'r--', lw=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("LightGBM: Actual vs Predicted")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(tuned_results_df['Model'], tuned_results_df['R2'], color='skyblue')
plt.xticks(rotation=45)
plt.title('Model Comparison by R² Score')
plt.ylabel('R² Score')
plt.tight_layout()
plt.show()
